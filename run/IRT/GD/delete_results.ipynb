# %% [markdown]
# ## Get final dataframe for excel file main page

# %%
import numpy as np
import os
import pandas as pd

NA_list = ['NA1', 'NA2']
for NA in NA_list:
    base_dir = f'./results_{NA}'
    results_df = pd.DataFrame(columns=[
        'auc_score', 'acc_score', 'fpr_score', 'precision_score',
        'auc_score_original', 'acc_score_original', 'fpr_score_original', 'precision_score_original',
        'Are NA1 NA2 Different?', "Cohen's d (NA1 vs NA2)", f"Cohen's d ({NA} vs Response)", f"Cohen's d ({NA} vs Problem)",
        "Cohen's d (Response vs Problem)", "Tukey_HSD"
    ])

    for subdir, dirs, files in os.walk(base_dir):
        results_found = False
        stats_found = False
        folder_name = os.path.basename(subdir)
        if folder_name not in results_df.index:
            results_df.loc[folder_name] = pd.Series({"auc_score": "NA", "acc_score": "NA", "fpr_score": "NA", "precision_score": "NA", 
                                                    "auc_score_original": "NA", "acc_score_original": "NA", "fpr_score_original": "NA", "precision_score_original": "NA",
                                                    'Are NA1 NA2 Different?': "NA", "Cohen's d (NA1 vs NA2)": "NA", f"Cohen's d ({NA} vs Response)": "NA", f"Cohen's d ({NA} vs Problem)": "NA",
        "Cohen's d (Response vs Problem)": "NA", "Tukey_HSD": "NA"})
        for file in files:
            try:

                if file.startswith('best_params'):
                    full_file_path = os.path.join(subdir, file)
                    with open(full_file_path, 'r') as f:
                        lines = f.readlines()
                        if len(lines) > 5:  # Ensure there are enough lines to process
                            try:
                                # Attempt to extract and process AUC scores
                                auc_scores = np.array([float(x.strip()) for x in lines[2].split(': ')[1].replace('[', '').replace(']', '').split(',')]) * 100
                                acc_scores = np.array([float(x.strip()) for x in lines[3].split(': ')[1].replace('[', '').replace(']', '').split(',')]) * 100
                                fpr_scores = np.array([float(x.strip()) for x in lines[4].split(': ')[1].replace('[', '').replace(']', '').split(',')]) * 100
                                precision_scores = np.array([float(x.strip()) for x in lines[5].split(': ')[1].replace('[', '').replace(']', '').split(',')]) * 100

                                # Calculate mean and standard deviation and update the DataFrame
                                results_df.loc[folder_name, 'auc_score'] = f"{np.mean(auc_scores):.2f} ± {np.std(auc_scores):.2f}"
                                results_df.loc[folder_name, 'acc_score'] = f"{np.mean(acc_scores):.2f} ± {np.std(acc_scores):.2f}"
                                results_df.loc[folder_name, 'fpr_score'] = f"{np.mean(fpr_scores):.2f} ± {np.std(fpr_scores):.2f}"
                                results_df.loc[folder_name, 'precision_score'] = f"{np.mean(precision_scores):.2f} ± {np.std(precision_scores):.2f}"
                                results_found = True
                            except Exception as e:
                                print(f"Error processing file {file} in {subdir}: {e}")
                        else:
                            print(f"Insufficient data in file {file} in {subdir}")
                            

                elif 'Original_results' in file:
                    full_file_path = os.path.join(subdir, file)
                    with open(full_file_path, 'r') as f:
                        lines = f.readlines()
                        if len(lines) > 4:  # Ensure there are enough lines to process
                            try:
                                auc_scores_original = np.array([float(x.strip()) for x in lines[1].strip().split(': ')[1].replace('[', '').replace(']', '').split(',')])*100
                                acc_scores_original = np.array([float(x.strip()) for x in lines[2].strip().split(': ')[1].replace('[', '').replace(']', '').split(',')])*100
                                fpr_scores_original = np.array([float(x.strip()) for x in lines[3].strip().split(': ')[1].replace('[', '').replace(']', '').split(',')])*100
                                precision_scores_original = np.array([float(x.strip()) for x in lines[4].strip().split(': ')[1].replace('[', '').replace(']', '').split(',')])*100
                                
                                results_df.loc[folder_name, 'auc_score_original'] = f"{np.mean(auc_scores_original):.2f} ± {np.std(auc_scores_original):.2f}"
                                results_df.loc[folder_name, 'acc_score_original'] = f"{np.mean(acc_scores_original):.2f} ± {np.std(acc_scores_original):.2f}"
                                results_df.loc[folder_name, 'fpr_score_original'] = f"{np.mean(fpr_scores_original):.2f} ± {np.std(fpr_scores_original):.2f}"
                                results_df.loc[folder_name, 'precision_score_original'] = f"{np.mean(precision_scores_original):.2f} ± {np.std(precision_scores_original):.2f}"
                                results_found = True
                            except Exception as e:
                                print(f"Error processing file {file} in {subdir}: {e}")
                                # results_df.loc[folder_name][['auc_score_original','acc_score_original','fpr_score_original','precision_score_original']] = ["NA"] * 4
                        else:
                            print(f"Insufficient data in file {file} in {subdir}")
                            # results_df.loc[folder_name] = ["NA"] * len(results_df.columns) 
                elif 'info_comparison' in file:
                    full_file_path = os.path.join(subdir, file)
                    info_df = pd.read_csv(full_file_path)
                    results_df.loc[folder_name, 'Are NA1 NA2 Different?'] = info_df['Are NA1 NA2 Different?'].iloc[0]
                    results_df.loc[folder_name, f"Cohen's d (NA1 vs NA2)"] = info_df["Cohen's d (NA1 vs NA2)"].iloc[0]
                    results_df.loc[folder_name, f"Cohen's d ({NA} vs Response)"] = info_df[f"Cohen's d ({NA} vs Response)"].iloc[0]
                    results_df.loc[folder_name, f"Cohen's d ({NA} vs Problem)"] = info_df[f"Cohen's d ({NA} vs Problem)"].iloc[0]
                    results_df.loc[folder_name, f"Cohen's d (Response vs Problem)"] = info_df[f"Cohen's d (Response vs Problem)"].iloc[0]
                    results_df.loc[folder_name, "Tukey_HSD"] = info_df["Tukey_HSD"].iloc[0]
                    stats_found = True
                else:
                    continue
            except:
                continue
    results_df.to_csv(f'./{NA}_11results.csv', encoding='utf-8-sig', index=True)

# %%
import pandas as pd
df_NA1= pd.read_csv("./NA1_11results.csv", encoding='utf-8') 
df_NA1 = df_NA1.iloc[1:,:]
df_NA2= pd.read_csv("./NA2_11results.csv", encoding='utf-8')
df_NA2 = df_NA2.iloc[1:,:]

# %%
def parse_mean_std(value):
    mean, std = value.split('±')
    return float(mean.strip()), float(std.strip())

criteria_list = ['auc', 'acc', 'fpr', 'precision'] 
results = {criteria: [] for criteria in criteria_list}

for index, row in df_NA1.iterrows():
    for criteria in criteria_list:
        mean, std = parse_mean_std(row[f'{criteria}_score'])
        original_mean, original_std = parse_mean_std(row[f'{criteria}_score_original'])
        abs_diff = abs(mean - original_mean)
        sum_std = std + original_std
        result = abs_diff - sum_std
  
        comparison_result = 'NE' if result > 0 else 'E'
        results[criteria].append(comparison_result)  # Store only the categorical result

for criteria in criteria_list:
    df_NA1[f'{criteria}_condition_met'] = results[criteria]
df_NA1.to_csv(f'./NA1_11results_condition.csv', encoding='utf-8-sig', index=False)

# %%
criteria_list = ['auc', 'acc', 'fpr', 'precision'] 
results = {criteria: [] for criteria in criteria_list}

for index, row in df_NA2.iterrows():
    for criteria in criteria_list:
        print('index:', index, row, criteria)
        mean, std = parse_mean_std(row[f'{criteria}_score'])
        original_mean, original_std = parse_mean_std(row[f'{criteria}_score_original'])
        abs_diff = abs(mean - original_mean)
        sum_std = std + original_std
        result = abs_diff - sum_std
  
        comparison_result = 'NE' if result > 0 else 'E'
        results[criteria].append(comparison_result)  # Store only the categorical result

for criteria in criteria_list:
    df_NA2[f'{criteria}_condition_met'] = results[criteria]
df_NA2.to_csv(f'./NA2_11results_condition.csv', encoding='utf-8-sig', index=False)
# Out:
# index: 1 Unnamed: 0                                                                        경제
# auc_score                                                               87.46 ± 2.16
# acc_score                                                               78.05 ± 3.08
# fpr_score                                                               14.63 ± 6.19
# precision_score                                                         76.07 ± 4.19
# auc_score_original                                                      69.39 ± 4.19
# acc_score_original                                                      64.88 ± 4.53
# fpr_score_original                                                     44.88 ± 11.17
# precision_score_original                                                70.40 ± 9.75
# Are NA1 NA2 Different?                                                         False
# Cohen's d (NA1 vs NA2)                                                      0.174876
# Cohen's d (NA2 vs Response)                                                 1.094755
# Cohen's d (NA2 vs Problem)                                                  1.330445
# Cohen's d (Response vs Problem)                                             0.124765
# Tukey_HSD                            Multiple Comparison of Means - Tukey HSD, FW...
# Name: 1, dtype: object auc
# index: 1 Unnamed: 0                                                                        경제
# auc_score                                                               87.46 ± 2.16
# acc_score                                                               78.05 ± 3.08
# fpr_score                                                               14.63 ± 6.19
# precision_score                                                         76.07 ± 4.19
# auc_score_original                                                      69.39 ± 4.19
# acc_score_original                                                      64.88 ± 4.53
# fpr_score_original                                                     44.88 ± 11.17
# precision_score_original                                                70.40 ± 9.75
# Are NA1 NA2 Different?                                                         False
# Cohen's d (NA1 vs NA2)                                                      0.174876
# Cohen's d (NA2 vs Response)                                                 1.094755
# Cohen's d (NA2 vs Problem)                                                  1.330445
# Cohen's d (Response vs Problem)                                             0.124765
# Tukey_HSD                            Multiple Comparison of Means - Tukey HSD, FW...
# Name: 1, dtype: object acc
# index: 1 Unnamed: 0                                                                        경제
# auc_score                                                               87.46 ± 2.16
# acc_score                                                               78.05 ± 3.08
# fpr_score                                                               14.63 ± 6.19
# precision_score                                                         76.07 ± 4.19
# auc_score_original                                                      69.39 ± 4.19
# acc_score_original                                                      64.88 ± 4.53
# fpr_score_original                                                     44.88 ± 11.17
# precision_score_original                                                70.40 ± 9.75
# Are NA1 NA2 Different?                                                         False
# Cohen's d (NA1 vs NA2)                                                      0.174876
# Cohen's d (NA2 vs Response)                                                 1.094755
# Cohen's d (NA2 vs Problem)                                                  1.330445
# Cohen's d (Response vs Problem)                                             0.124765
# Tukey_HSD                            Multiple Comparison of Means - Tukey HSD, FW...
# Name: 1, dtype: object fpr
# index: 1 Unnamed: 0                                                                        경제
# auc_score                                                               87.46 ± 2.16
# acc_score                                                               78.05 ± 3.08
# fpr_score                                                               14.63 ± 6.19
# precision_score                                                         76.07 ± 4.19
# auc_score_original                                                      69.39 ± 4.19
# acc_score_original                                                      64.88 ± 4.53
# fpr_score_original                                                     44.88 ± 11.17
# precision_score_original                                                70.40 ± 9.75
# Are NA1 NA2 Different?                                                         False
# Cohen's d (NA1 vs NA2)                                                      0.174876
# Cohen's d (NA2 vs Response)                                                 1.094755
# Cohen's d (NA2 vs Problem)                                                  1.330445
# Cohen's d (Response vs Problem)                                             0.124765
# Tukey_HSD                            Multiple Comparison of Means - Tukey HSD, FW...
# Name: 1, dtype: object precision
# index: 2 Unnamed: 0                                                                     사회?문화
# auc_score                                                               87.32 ± 2.32
# acc_score                                                               80.45 ± 1.73
# fpr_score                                                               15.90 ± 2.69
# precision_score                                                         79.33 ± 2.06
# auc_score_original                                                      78.88 ± 1.38
# acc_score_original                                                      73.19 ± 1.60
# fpr_score_original                                                      27.46 ± 5.51
# precision_score_original                                                73.44 ± 3.22
# Are NA1 NA2 Different?                                                         False
# Cohen's d (NA1 vs NA2)                                                      0.505942
# Cohen's d (NA2 vs Response)                                                 0.370625
# Cohen's d (NA2 vs Problem)                                                  0.820434
# Cohen's d (Response vs Problem)                                             0.232446
# Tukey_HSD                          No significant differences found by ANOVA.\n M...
# Name: 2, dtype: object auc
# index: 2 Unnamed: 0                                                                     사회?문화
# auc_score                                                               87.32 ± 2.32
# acc_score                                                               80.45 ± 1.73
# fpr_score                                                               15.90 ± 2.69
# precision_score                                                         79.33 ± 2.06
# auc_score_original                                                      78.88 ± 1.38
# acc_score_original                                                      73.19 ± 1.60
# fpr_score_original                                                      27.46 ± 5.51
# precision_score_original                                                73.44 ± 3.22
# Are NA1 NA2 Different?                                                         False
# Cohen's d (NA1 vs NA2)                                                      0.505942
# Cohen's d (NA2 vs Response)                                                 0.370625
# Cohen's d (NA2 vs Problem)                                                  0.820434
# Cohen's d (Response vs Problem)                                             0.232446
# Tukey_HSD                          No significant differences found by ANOVA.\n M...
# Name: 2, dtype: object acc
# index: 2 Unnamed: 0                                                                     사회?문화
# auc_score                                                               87.32 ± 2.32
# acc_score                                                               80.45 ± 1.73
# fpr_score                                                               15.90 ± 2.69
# precision_score                                                         79.33 ± 2.06
# auc_score_original                                                      78.88 ± 1.38
# acc_score_original                                                      73.19 ± 1.60
# fpr_score_original                                                      27.46 ± 5.51
# precision_score_original                                                73.44 ± 3.22
# Are NA1 NA2 Different?                                                         False
# Cohen's d (NA1 vs NA2)                                                      0.505942
# Cohen's d (NA2 vs Response)                                                 0.370625
# Cohen's d (NA2 vs Problem)                                                  0.820434
# Cohen's d (Response vs Problem)                                             0.232446
# Tukey_HSD                          No significant differences found by ANOVA.\n M...
# Name: 2, dtype: object fpr
# index: 2 Unnamed: 0                                                                     사회?문화
# auc_score                                                               87.32 ± 2.32
# acc_score                                                               80.45 ± 1.73
# fpr_score                                                               15.90 ± 2.69
# precision_score                                                         79.33 ± 2.06
# auc_score_original                                                      78.88 ± 1.38
# acc_score_original                                                      73.19 ± 1.60
# fpr_score_original                                                      27.46 ± 5.51
# precision_score_original                                                73.44 ± 3.22
# Are NA1 NA2 Different?                                                         False
# Cohen's d (NA1 vs NA2)                                                      0.505942
# Cohen's d (NA2 vs Response)                                                 0.370625
# Cohen's d (NA2 vs Problem)                                                  0.820434
# Cohen's d (Response vs Problem)                                             0.232446
# Tukey_HSD                          No significant differences found by ANOVA.\n M...
# Name: 2, dtype: object precision
# index: 3 Unnamed: 0                                                                       세계사
# auc_score                                                               88.82 ± 1.74
# acc_score                                                               80.10 ± 1.90
# fpr_score                                                               11.16 ± 3.22
# precision_score                                                         77.16 ± 2.95
# auc_score_original                                                      78.03 ± 2.54
# acc_score_original                                                      72.80 ± 2.48
# fpr_score_original                                                     37.74 ± 14.43
# precision_score_original                                                76.67 ± 4.36
# Are NA1 NA2 Different?                                                         False
# Cohen's d (NA1 vs NA2)                                                     -0.182361
# Cohen's d (NA2 vs Response)                                                 0.527047
# Cohen's d (NA2 vs Problem)                                                  1.051503
# Cohen's d (Response vs Problem)                                             0.393411
# Tukey_HSD                          No significant differences found by ANOVA.\n M...
# Name: 3, dtype: object auc
# index: 3 Unnamed: 0                                                                       세계사
# auc_score                                                               88.82 ± 1.74
# acc_score                                                               80.10 ± 1.90
# fpr_score                                                               11.16 ± 3.22
# precision_score                                                         77.16 ± 2.95
# auc_score_original                                                      78.03 ± 2.54
# acc_score_original                                                      72.80 ± 2.48
# fpr_score_original                                                     37.74 ± 14.43
# precision_score_original                                                76.67 ± 4.36
# Are NA1 NA2 Different?                                                         False
# Cohen's d (NA1 vs NA2)                                                     -0.182361
# Cohen's d (NA2 vs Response)                                                 0.527047
# Cohen's d (NA2 vs Problem)                                                  1.051503
# Cohen's d (Response vs Problem)                                             0.393411
# Tukey_HSD                          No significant differences found by ANOVA.\n M...
# Name: 3, dtype: object acc
# index: 3 Unnamed: 0                                                                       세계사
# auc_score                                                               88.82 ± 1.74
# acc_score                                                               80.10 ± 1.90
# fpr_score                                                               11.16 ± 3.22
# precision_score                                                         77.16 ± 2.95
# auc_score_original                                                      78.03 ± 2.54
# acc_score_original                                                      72.80 ± 2.48
# fpr_score_original                                                     37.74 ± 14.43
# precision_score_original                                                76.67 ± 4.36
# Are NA1 NA2 Different?                                                         False
# Cohen's d (NA1 vs NA2)                                                     -0.182361
# Cohen's d (NA2 vs Response)                                                 0.527047
# Cohen's d (NA2 vs Problem)                                                  1.051503
# Cohen's d (Response vs Problem)                                             0.393411
# Tukey_HSD                          No significant differences found by ANOVA.\n M...
# Name: 3, dtype: object fpr
# index: 3 Unnamed: 0                                                                       세계사
# auc_score                                                               88.82 ± 1.74
# acc_score                                                               80.10 ± 1.90
# fpr_score                                                               11.16 ± 3.22
# precision_score                                                         77.16 ± 2.95
# auc_score_original                                                      78.03 ± 2.54
# acc_score_original                                                      72.80 ± 2.48
# fpr_score_original                                                     37.74 ± 14.43
# precision_score_original                                                76.67 ± 4.36
# Are NA1 NA2 Different?                                                         False
# Cohen's d (NA1 vs NA2)                                                     -0.182361
# Cohen's d (NA2 vs Response)                                                 0.527047
# Cohen's d (NA2 vs Problem)                                                  1.051503
# Cohen's d (Response vs Problem)                                             0.393411
# Tukey_HSD                          No significant differences found by ANOVA.\n M...
# Name: 3, dtype: object precision
# index: 4 Unnamed: 0                                                                    윤리와 사상
# auc_score                                                               87.35 ± 0.61
# acc_score                                                               80.28 ± 2.79
# fpr_score                                                               11.91 ± 3.06
# precision_score                                                         76.80 ± 4.55
# auc_score_original                                                      75.67 ± 3.20
# acc_score_original                                                      71.76 ± 3.00
# fpr_score_original                                                      37.39 ± 9.21
# precision_score_original                                                76.27 ± 5.42
# Are NA1 NA2 Different?                                                         False
# Cohen's d (NA1 vs NA2)                                                     -0.565572
# Cohen's d (NA2 vs Response)                                                 0.805893
# Cohen's d (NA2 vs Problem)                                                  1.122123
# Cohen's d (Response vs Problem)                                             0.604197
# Tukey_HSD                            Multiple Comparison of Means - Tukey HSD, FW...
# Name: 4, dtype: object auc
# index: 4 Unnamed: 0                                                                    윤리와 사상
# auc_score                                                               87.35 ± 0.61
# acc_score                                                               80.28 ± 2.79
# fpr_score                                                               11.91 ± 3.06
# precision_score                                                         76.80 ± 4.55
# auc_score_original                                                      75.67 ± 3.20
# acc_score_original                                                      71.76 ± 3.00
# fpr_score_original                                                      37.39 ± 9.21
# precision_score_original                                                76.27 ± 5.42
# Are NA1 NA2 Different?                                                         False
# Cohen's d (NA1 vs NA2)                                                     -0.565572
# Cohen's d (NA2 vs Response)                                                 0.805893
# Cohen's d (NA2 vs Problem)                                                  1.122123
# Cohen's d (Response vs Problem)                                             0.604197
# Tukey_HSD                            Multiple Comparison of Means - Tukey HSD, FW...
# Name: 4, dtype: object acc
# index: 4 Unnamed: 0                                                                    윤리와 사상
# auc_score                                                               87.35 ± 0.61
# acc_score                                                               80.28 ± 2.79
# fpr_score                                                               11.91 ± 3.06
# precision_score                                                         76.80 ± 4.55
# auc_score_original                                                      75.67 ± 3.20
# acc_score_original                                                      71.76 ± 3.00
# fpr_score_original                                                      37.39 ± 9.21
# precision_score_original                                                76.27 ± 5.42
# Are NA1 NA2 Different?                                                         False
# Cohen's d (NA1 vs NA2)                                                     -0.565572
# Cohen's d (NA2 vs Response)                                                 0.805893
# Cohen's d (NA2 vs Problem)                                                  1.122123
# Cohen's d (Response vs Problem)                                             0.604197
# Tukey_HSD                            Multiple Comparison of Means - Tukey HSD, FW...
# Name: 4, dtype: object fpr
# index: 4 Unnamed: 0                                                                    윤리와 사상
# auc_score                                                               87.35 ± 0.61
# acc_score                                                               80.28 ± 2.79
# fpr_score                                                               11.91 ± 3.06
# precision_score                                                         76.80 ± 4.55
# auc_score_original                                                      75.67 ± 3.20
# acc_score_original                                                      71.76 ± 3.00
# fpr_score_original                                                      37.39 ± 9.21
# precision_score_original                                                76.27 ± 5.42
# Are NA1 NA2 Different?                                                         False
# Cohen's d (NA1 vs NA2)                                                     -0.565572
# Cohen's d (NA2 vs Response)                                                 0.805893
# Cohen's d (NA2 vs Problem)                                                  1.122123
# Cohen's d (Response vs Problem)                                             0.604197
# Tukey_HSD                            Multiple Comparison of Means - Tukey HSD, FW...
# Name: 4, dtype: object precision
# index: 5 Unnamed: 0                                                                      세계지리
# auc_score                                                               80.86 ± 4.51
# acc_score                                                               77.18 ± 2.42
# fpr_score                                                               27.32 ± 6.93
# precision_score                                                         77.99 ± 2.92
# auc_score_original                                                      71.34 ± 2.44
# acc_score_original                                                      72.38 ± 2.04
# fpr_score_original                                                      49.15 ± 5.43
# precision_score_original                                                79.96 ± 3.70
# Are NA1 NA2 Different?                                                         False
# Cohen's d (NA1 vs NA2)                                                      0.075969
# Cohen's d (NA2 vs Response)                                                 0.775796
# Cohen's d (NA2 vs Problem)                                                  1.132691
# Cohen's d (Response vs Problem)                                             0.363715
# Tukey_HSD                            Multiple Comparison of Means - Tukey HSD, FW...
# Name: 5, dtype: object auc
# index: 5 Unnamed: 0                                                                      세계지리
# auc_score                                                               80.86 ± 4.51
# acc_score                                                               77.18 ± 2.42
# fpr_score                                                               27.32 ± 6.93
# precision_score                                                         77.99 ± 2.92
# auc_score_original                                                      71.34 ± 2.44
# acc_score_original                                                      72.38 ± 2.04
# fpr_score_original                                                      49.15 ± 5.43
# precision_score_original                                                79.96 ± 3.70
# Are NA1 NA2 Different?                                                         False
# Cohen's d (NA1 vs NA2)                                                      0.075969
# Cohen's d (NA2 vs Response)                                                 0.775796
# Cohen's d (NA2 vs Problem)                                                  1.132691
# Cohen's d (Response vs Problem)                                             0.363715
# Tukey_HSD                            Multiple Comparison of Means - Tukey HSD, FW...
# Name: 5, dtype: object acc
# index: 5 Unnamed: 0                                                                      세계지리
# auc_score                                                               80.86 ± 4.51
# acc_score                                                               77.18 ± 2.42
# fpr_score                                                               27.32 ± 6.93
# precision_score                                                         77.99 ± 2.92
# auc_score_original                                                      71.34 ± 2.44
# acc_score_original                                                      72.38 ± 2.04
# fpr_score_original                                                      49.15 ± 5.43
# precision_score_original                                                79.96 ± 3.70
# Are NA1 NA2 Different?                                                         False
# Cohen's d (NA1 vs NA2)                                                      0.075969
# Cohen's d (NA2 vs Response)                                                 0.775796
# Cohen's d (NA2 vs Problem)                                                  1.132691
# Cohen's d (Response vs Problem)                                             0.363715
# Tukey_HSD                            Multiple Comparison of Means - Tukey HSD, FW...
# Name: 5, dtype: object fpr
# index: 5 Unnamed: 0                                                                      세계지리
# auc_score                                                               80.86 ± 4.51
# acc_score                                                               77.18 ± 2.42
# fpr_score                                                               27.32 ± 6.93
# precision_score                                                         77.99 ± 2.92
# auc_score_original                                                      71.34 ± 2.44
# acc_score_original                                                      72.38 ± 2.04
# fpr_score_original                                                      49.15 ± 5.43
# precision_score_original                                                79.96 ± 3.70
# Are NA1 NA2 Different?                                                         False
# Cohen's d (NA1 vs NA2)                                                      0.075969
# Cohen's d (NA2 vs Response)                                                 0.775796
# Cohen's d (NA2 vs Problem)                                                  1.132691
# Cohen's d (Response vs Problem)                                             0.363715
# Tukey_HSD                            Multiple Comparison of Means - Tukey HSD, FW...
# Name: 5, dtype: object precision
# index: 6 Unnamed: 0                                                                    생활과 윤리
# auc_score                                                               84.67 ± 1.71
# acc_score                                                               78.05 ± 0.88
# fpr_score                                                               21.23 ± 3.05
# precision_score                                                         77.87 ± 1.28
# auc_score_original                                                      76.59 ± 1.41
# acc_score_original                                                      71.21 ± 0.76
# fpr_score_original                                                      32.40 ± 5.19
# precision_score_original                                                72.83 ± 2.28
# Are NA1 NA2 Different?                                                          True
# Cohen's d (NA1 vs NA2)                                                     -1.174691
# Cohen's d (NA2 vs Response)                                                 0.921429
# Cohen's d (NA2 vs Problem)                                                  0.928824
# Cohen's d (Response vs Problem)                                             0.064921
# Tukey_HSD                          No significant differences found by ANOVA.\n M...
# Name: 6, dtype: object auc
# index: 6 Unnamed: 0                                                                    생활과 윤리
# auc_score                                                               84.67 ± 1.71
# acc_score                                                               78.05 ± 0.88
# fpr_score                                                               21.23 ± 3.05
# precision_score                                                         77.87 ± 1.28
# auc_score_original                                                      76.59 ± 1.41
# acc_score_original                                                      71.21 ± 0.76
# fpr_score_original                                                      32.40 ± 5.19
# precision_score_original                                                72.83 ± 2.28
# Are NA1 NA2 Different?                                                          True
# Cohen's d (NA1 vs NA2)                                                     -1.174691
# Cohen's d (NA2 vs Response)                                                 0.921429
# Cohen's d (NA2 vs Problem)                                                  0.928824
# Cohen's d (Response vs Problem)                                             0.064921
# Tukey_HSD                          No significant differences found by ANOVA.\n M...
# Name: 6, dtype: object acc
# index: 6 Unnamed: 0                                                                    생활과 윤리
# auc_score                                                               84.67 ± 1.71
# acc_score                                                               78.05 ± 0.88
# fpr_score                                                               21.23 ± 3.05
# precision_score                                                         77.87 ± 1.28
# auc_score_original                                                      76.59 ± 1.41
# acc_score_original                                                      71.21 ± 0.76
# fpr_score_original                                                      32.40 ± 5.19
# precision_score_original                                                72.83 ± 2.28
# Are NA1 NA2 Different?                                                          True
# Cohen's d (NA1 vs NA2)                                                     -1.174691
# Cohen's d (NA2 vs Response)                                                 0.921429
# Cohen's d (NA2 vs Problem)                                                  0.928824
# Cohen's d (Response vs Problem)                                             0.064921
# Tukey_HSD                          No significant differences found by ANOVA.\n M...
# Name: 6, dtype: object fpr
# index: 6 Unnamed: 0                                                                    생활과 윤리
# auc_score                                                               84.67 ± 1.71
# acc_score                                                               78.05 ± 0.88
# fpr_score                                                               21.23 ± 3.05
# precision_score                                                         77.87 ± 1.28
# auc_score_original                                                      76.59 ± 1.41
# acc_score_original                                                      71.21 ± 0.76
# fpr_score_original                                                      32.40 ± 5.19
# precision_score_original                                                72.83 ± 2.28
# Are NA1 NA2 Different?                                                          True
# Cohen's d (NA1 vs NA2)                                                     -1.174691
# Cohen's d (NA2 vs Response)                                                 0.921429
# Cohen's d (NA2 vs Problem)                                                  0.928824
# Cohen's d (Response vs Problem)                                             0.064921
# Tukey_HSD                          No significant differences found by ANOVA.\n M...
# Name: 6, dtype: object precision
# index: 7 Unnamed: 0                                                                     동아시아사
# auc_score                                                               80.05 ± 3.32
# acc_score                                                               78.09 ± 2.55
# fpr_score                                                               28.53 ± 7.36
# precision_score                                                         79.44 ± 3.51
# auc_score_original                                                      72.67 ± 4.45
# acc_score_original                                                      75.88 ± 2.99
# fpr_score_original                                                     70.27 ± 12.94
# precision_score_original                                                88.44 ± 4.46
# Are NA1 NA2 Different?                                                          True
# Cohen's d (NA1 vs NA2)                                                     -1.643904
# Cohen's d (NA2 vs Response)                                                -0.586094
# Cohen's d (NA2 vs Problem)                                                  0.281152
# Cohen's d (Response vs Problem)                                             0.834453
# Tukey_HSD                          No significant differences found by ANOVA.\n M...
# Name: 7, dtype: object auc
# index: 7 Unnamed: 0                                                                     동아시아사
# auc_score                                                               80.05 ± 3.32
# acc_score                                                               78.09 ± 2.55
# fpr_score                                                               28.53 ± 7.36
# precision_score                                                         79.44 ± 3.51
# auc_score_original                                                      72.67 ± 4.45
# acc_score_original                                                      75.88 ± 2.99
# fpr_score_original                                                     70.27 ± 12.94
# precision_score_original                                                88.44 ± 4.46
# Are NA1 NA2 Different?                                                          True
# Cohen's d (NA1 vs NA2)                                                     -1.643904
# Cohen's d (NA2 vs Response)                                                -0.586094
# Cohen's d (NA2 vs Problem)                                                  0.281152
# Cohen's d (Response vs Problem)                                             0.834453
# Tukey_HSD                          No significant differences found by ANOVA.\n M...
# Name: 7, dtype: object acc
# index: 7 Unnamed: 0                                                                     동아시아사
# auc_score                                                               80.05 ± 3.32
# acc_score                                                               78.09 ± 2.55
# fpr_score                                                               28.53 ± 7.36
# precision_score                                                         79.44 ± 3.51
# auc_score_original                                                      72.67 ± 4.45
# acc_score_original                                                      75.88 ± 2.99
# fpr_score_original                                                     70.27 ± 12.94
# precision_score_original                                                88.44 ± 4.46
# Are NA1 NA2 Different?                                                          True
# Cohen's d (NA1 vs NA2)                                                     -1.643904
# Cohen's d (NA2 vs Response)                                                -0.586094
# Cohen's d (NA2 vs Problem)                                                  0.281152
# Cohen's d (Response vs Problem)                                             0.834453
# Tukey_HSD                          No significant differences found by ANOVA.\n M...
# Name: 7, dtype: object fpr
# index: 7 Unnamed: 0                                                                     동아시아사
# auc_score                                                               80.05 ± 3.32
# acc_score                                                               78.09 ± 2.55
# fpr_score                                                               28.53 ± 7.36
# precision_score                                                         79.44 ± 3.51
# auc_score_original                                                      72.67 ± 4.45
# acc_score_original                                                      75.88 ± 2.99
# fpr_score_original                                                     70.27 ± 12.94
# precision_score_original                                                88.44 ± 4.46
# Are NA1 NA2 Different?                                                          True
# Cohen's d (NA1 vs NA2)                                                     -1.643904
# Cohen's d (NA2 vs Response)                                                -0.586094
# Cohen's d (NA2 vs Problem)                                                  0.281152
# Cohen's d (Response vs Problem)                                             0.834453
# Tukey_HSD                          No significant differences found by ANOVA.\n M...
# Name: 7, dtype: object precision
# index: 8 Unnamed: 0                                                                      한국지리
# auc_score                                                               85.43 ± 3.83
# acc_score                                                               79.93 ± 3.09
# fpr_score                                                               15.55 ± 5.39
# precision_score                                                         78.89 ± 4.08
# auc_score_original                                                      75.93 ± 2.79
# acc_score_original                                                      71.59 ± 2.00
# fpr_score_original                                                      26.74 ± 7.07
# precision_score_original                                                70.92 ± 3.39
# Are NA1 NA2 Different?                                                         False
# Cohen's d (NA1 vs NA2)                                                       0.09247
# Cohen's d (NA2 vs Response)                                                 0.742111
# Cohen's d (NA2 vs Problem)                                                  0.517495
# Cohen's d (Response vs Problem)                                            -0.217013
# Tukey_HSD                          No significant differences found by ANOVA.\n M...
# Name: 8, dtype: object auc
# index: 8 Unnamed: 0                                                                      한국지리
# auc_score                                                               85.43 ± 3.83
# acc_score                                                               79.93 ± 3.09
# fpr_score                                                               15.55 ± 5.39
# precision_score                                                         78.89 ± 4.08
# auc_score_original                                                      75.93 ± 2.79
# acc_score_original                                                      71.59 ± 2.00
# fpr_score_original                                                      26.74 ± 7.07
# precision_score_original                                                70.92 ± 3.39
# Are NA1 NA2 Different?                                                         False
# Cohen's d (NA1 vs NA2)                                                       0.09247
# Cohen's d (NA2 vs Response)                                                 0.742111
# Cohen's d (NA2 vs Problem)                                                  0.517495
# Cohen's d (Response vs Problem)                                            -0.217013
# Tukey_HSD                          No significant differences found by ANOVA.\n M...
# Name: 8, dtype: object acc
# index: 8 Unnamed: 0                                                                      한국지리
# auc_score                                                               85.43 ± 3.83
# acc_score                                                               79.93 ± 3.09
# fpr_score                                                               15.55 ± 5.39
# precision_score                                                         78.89 ± 4.08
# auc_score_original                                                      75.93 ± 2.79
# acc_score_original                                                      71.59 ± 2.00
# fpr_score_original                                                      26.74 ± 7.07
# precision_score_original                                                70.92 ± 3.39
# Are NA1 NA2 Different?                                                         False
# Cohen's d (NA1 vs NA2)                                                       0.09247
# Cohen's d (NA2 vs Response)                                                 0.742111
# Cohen's d (NA2 vs Problem)                                                  0.517495
# Cohen's d (Response vs Problem)                                            -0.217013
# Tukey_HSD                          No significant differences found by ANOVA.\n M...
# Name: 8, dtype: object fpr
# index: 8 Unnamed: 0                                                                      한국지리
# auc_score                                                               85.43 ± 3.83
# acc_score                                                               79.93 ± 3.09
# fpr_score                                                               15.55 ± 5.39
# precision_score                                                         78.89 ± 4.08
# auc_score_original                                                      75.93 ± 2.79
# acc_score_original                                                      71.59 ± 2.00
# fpr_score_original                                                      26.74 ± 7.07
# precision_score_original                                                70.92 ± 3.39
# Are NA1 NA2 Different?                                                         False
# Cohen's d (NA1 vs NA2)                                                       0.09247
# Cohen's d (NA2 vs Response)                                                 0.742111
# Cohen's d (NA2 vs Problem)                                                  0.517495
# Cohen's d (Response vs Problem)                                            -0.217013
# Tukey_HSD                          No significant differences found by ANOVA.\n M...
# Name: 8, dtype: object precision
# index: 9 Unnamed: 0                                                                      물리학Ⅱ
# auc_score                                                               88.88 ± 8.59
# acc_score                                                               88.64 ± 4.13
# fpr_score                                                                3.07 ± 4.98
# precision_score                                                        62.23 ± 14.48
# auc_score_original                                                     58.29 ± 17.11
# acc_score_original                                                      45.79 ± 7.79
# fpr_score_original                                                     94.42 ± 10.71
# precision_score_original                                               100.00 ± 0.00
# Are NA1 NA2 Different?                                                         False
# Cohen's d (NA1 vs NA2)                                                     -0.681533
# Cohen's d (NA2 vs Response)                                                -0.447213
# Cohen's d (NA2 vs Problem)                                                  0.823854
# Cohen's d (Response vs Problem)                                             0.447214
# Tukey_HSD                          No significant differences found by ANOVA.\n  ...
# Name: 9, dtype: object auc
# index: 9 Unnamed: 0                                                                      물리학Ⅱ
# auc_score                                                               88.88 ± 8.59
# acc_score                                                               88.64 ± 4.13
# fpr_score                                                                3.07 ± 4.98
# precision_score                                                        62.23 ± 14.48
# auc_score_original                                                     58.29 ± 17.11
# acc_score_original                                                      45.79 ± 7.79
# fpr_score_original                                                     94.42 ± 10.71
# precision_score_original                                               100.00 ± 0.00
# Are NA1 NA2 Different?                                                         False
# Cohen's d (NA1 vs NA2)                                                     -0.681533
# Cohen's d (NA2 vs Response)                                                -0.447213
# Cohen's d (NA2 vs Problem)                                                  0.823854
# Cohen's d (Response vs Problem)                                             0.447214
# Tukey_HSD                          No significant differences found by ANOVA.\n  ...
# Name: 9, dtype: object acc
# index: 9 Unnamed: 0                                                                      물리학Ⅱ
# auc_score                                                               88.88 ± 8.59
# acc_score                                                               88.64 ± 4.13
# fpr_score                                                                3.07 ± 4.98
# precision_score                                                        62.23 ± 14.48
# auc_score_original                                                     58.29 ± 17.11
# acc_score_original                                                      45.79 ± 7.79
# fpr_score_original                                                     94.42 ± 10.71
# precision_score_original                                               100.00 ± 0.00
# Are NA1 NA2 Different?                                                         False
# Cohen's d (NA1 vs NA2)                                                     -0.681533
# Cohen's d (NA2 vs Response)                                                -0.447213
# Cohen's d (NA2 vs Problem)                                                  0.823854
# Cohen's d (Response vs Problem)                                             0.447214
# Tukey_HSD                          No significant differences found by ANOVA.\n  ...
# Name: 9, dtype: object fpr
# index: 9 Unnamed: 0                                                                      물리학Ⅱ
# auc_score                                                               88.88 ± 8.59
# acc_score                                                               88.64 ± 4.13
# fpr_score                                                                3.07 ± 4.98
# precision_score                                                        62.23 ± 14.48
# auc_score_original                                                     58.29 ± 17.11
# acc_score_original                                                      45.79 ± 7.79
# fpr_score_original                                                     94.42 ± 10.71
# precision_score_original                                               100.00 ± 0.00
# Are NA1 NA2 Different?                                                         False
# Cohen's d (NA1 vs NA2)                                                     -0.681533
# Cohen's d (NA2 vs Response)                                                -0.447213
# Cohen's d (NA2 vs Problem)                                                  0.823854
# Cohen's d (Response vs Problem)                                             0.447214
# Tukey_HSD                          No significant differences found by ANOVA.\n  ...
# Name: 9, dtype: object precision
# index: 10 Unnamed: 0                                                                       화학Ⅰ
# auc_score                                                               95.09 ± 0.73
# acc_score                                                               92.89 ± 0.72
# fpr_score                                                               12.01 ± 1.73
# precision_score                                                         94.46 ± 0.81
# auc_score_original                                                      80.01 ± 1.40
# acc_score_original                                                      80.05 ± 1.33
# fpr_score_original                                                      45.24 ± 5.95
# ...
# acc_score_original                                                      56.39 ± 6.05
# fpr_score_original                                                     80.17 ± 22.54
# precision_score_original                                               83.71 ± 18.96
# Are NA1 NA2 Different?                                                          True
# Cohen's d (NA1 vs NA2)                                                      -1.83736
# Cohen's d (NA2 vs Response)                                                -0.447213
# Cohen's d (NA2 vs Problem)                                                  0.739437
# Cohen's d (Response vs Problem)                                             0.447214
# Tukey_HSD                          No significant differences found by ANOVA.\n  ...
# Name: 13, dtype: object acc
# index: 13 Unnamed: 0                                                                     생명과학Ⅱ
# auc_score                                                               87.12 ± 6.40
# acc_score                                                               80.84 ± 5.34
# fpr_score                                                               10.59 ± 5.92
# precision_score                                                        68.33 ± 11.78
# auc_score_original                                                     55.21 ± 12.56
# acc_score_original                                                      56.39 ± 6.05
# fpr_score_original                                                     80.17 ± 22.54
# precision_score_original                                               83.71 ± 18.96
# Are NA1 NA2 Different?                                                          True
# Cohen's d (NA1 vs NA2)                                                      -1.83736
# Cohen's d (NA2 vs Response)                                                -0.447213
# Cohen's d (NA2 vs Problem)                                                  0.739437
# Cohen's d (Response vs Problem)                                             0.447214
# Tukey_HSD                          No significant differences found by ANOVA.\n  ...
# Name: 13, dtype: object fpr
# index: 13 Unnamed: 0                                                                     생명과학Ⅱ
# auc_score                                                               87.12 ± 6.40
# acc_score                                                               80.84 ± 5.34
# fpr_score                                                               10.59 ± 5.92
# precision_score                                                        68.33 ± 11.78
# auc_score_original                                                     55.21 ± 12.56
# acc_score_original                                                      56.39 ± 6.05
# fpr_score_original                                                     80.17 ± 22.54
# precision_score_original                                               83.71 ± 18.96
# Are NA1 NA2 Different?                                                          True
# Cohen's d (NA1 vs NA2)                                                      -1.83736
# Cohen's d (NA2 vs Response)                                                -0.447213
# Cohen's d (NA2 vs Problem)                                                  0.739437
# Cohen's d (Response vs Problem)                                             0.447214
# Tukey_HSD                          No significant differences found by ANOVA.\n  ...
# Name: 13, dtype: object precision
# index: 14 Unnamed: 0                                                                     지구과학Ⅰ
# auc_score                                                               77.22 ± 1.81
# acc_score                                                               71.24 ± 1.41
# fpr_score                                                               22.85 ± 4.98
# precision_score                                                         68.82 ± 2.60
# auc_score_original                                                      73.43 ± 1.00
# acc_score_original                                                      68.14 ± 1.82
# fpr_score_original                                                      38.75 ± 6.31
# precision_score_original                                                71.76 ± 4.70
# Are NA1 NA2 Different?                                                          True
# Cohen's d (NA1 vs NA2)                                                     -1.006056
# Cohen's d (NA2 vs Response)                                                 1.086544
# Cohen's d (NA2 vs Problem)                                                  1.281906
# Cohen's d (Response vs Problem)                                              0.26548
# Tukey_HSD                            Multiple Comparison of Means - Tukey HSD, FW...
# Name: 14, dtype: object auc
# index: 14 Unnamed: 0                                                                     지구과학Ⅰ
# auc_score                                                               77.22 ± 1.81
# acc_score                                                               71.24 ± 1.41
# fpr_score                                                               22.85 ± 4.98
# precision_score                                                         68.82 ± 2.60
# auc_score_original                                                      73.43 ± 1.00
# acc_score_original                                                      68.14 ± 1.82
# fpr_score_original                                                      38.75 ± 6.31
# precision_score_original                                                71.76 ± 4.70
# Are NA1 NA2 Different?                                                          True
# Cohen's d (NA1 vs NA2)                                                     -1.006056
# Cohen's d (NA2 vs Response)                                                 1.086544
# Cohen's d (NA2 vs Problem)                                                  1.281906
# Cohen's d (Response vs Problem)                                              0.26548
# Tukey_HSD                            Multiple Comparison of Means - Tukey HSD, FW...
# Name: 14, dtype: object acc
# index: 14 Unnamed: 0                                                                     지구과학Ⅰ
# auc_score                                                               77.22 ± 1.81
# acc_score                                                               71.24 ± 1.41
# fpr_score                                                               22.85 ± 4.98
# precision_score                                                         68.82 ± 2.60
# auc_score_original                                                      73.43 ± 1.00
# acc_score_original                                                      68.14 ± 1.82
# fpr_score_original                                                      38.75 ± 6.31
# precision_score_original                                                71.76 ± 4.70
# Are NA1 NA2 Different?                                                          True
# Cohen's d (NA1 vs NA2)                                                     -1.006056
# Cohen's d (NA2 vs Response)                                                 1.086544
# Cohen's d (NA2 vs Problem)                                                  1.281906
# Cohen's d (Response vs Problem)                                              0.26548
# Tukey_HSD                            Multiple Comparison of Means - Tukey HSD, FW...
# Name: 14, dtype: object fpr
# index: 14 Unnamed: 0                                                                     지구과학Ⅰ
# auc_score                                                               77.22 ± 1.81
# acc_score                                                               71.24 ± 1.41
# fpr_score                                                               22.85 ± 4.98
# precision_score                                                         68.82 ± 2.60
# auc_score_original                                                      73.43 ± 1.00
# acc_score_original                                                      68.14 ± 1.82
# fpr_score_original                                                      38.75 ± 6.31
# precision_score_original                                                71.76 ± 4.70
# Are NA1 NA2 Different?                                                          True
# Cohen's d (NA1 vs NA2)                                                     -1.006056
# Cohen's d (NA2 vs Response)                                                 1.086544
# Cohen's d (NA2 vs Problem)                                                  1.281906
# Cohen's d (Response vs Problem)                                              0.26548
# Tukey_HSD                            Multiple Comparison of Means - Tukey HSD, FW...
# Name: 14, dtype: object precision
# index: 15 Unnamed: 0                                                                     지구과학Ⅱ
# auc_score                                                              82.57 ± 13.05
# acc_score                                                               87.17 ± 8.93
# fpr_score                                                                2.87 ± 3.79
# precision_score                                                        51.29 ± 24.69
# auc_score_original                                                     51.73 ± 13.22
# acc_score_original                                                     36.25 ± 14.05
# fpr_score_original                                                     88.18 ± 14.57
# precision_score_original                                               84.00 ± 17.22
# Are NA1 NA2 Different?                                                         False
# Cohen's d (NA1 vs NA2)                                                      0.655169
# Cohen's d (NA2 vs Response)                                                -0.447212
# Cohen's d (NA2 vs Problem)                                                  0.728185
# Cohen's d (Response vs Problem)                                             0.447214
# Tukey_HSD                          No significant differences found by ANOVA.\n  ...
# Name: 15, dtype: object auc
# index: 15 Unnamed: 0                                                                     지구과학Ⅱ
# auc_score                                                              82.57 ± 13.05
# acc_score                                                               87.17 ± 8.93
# fpr_score                                                                2.87 ± 3.79
# precision_score                                                        51.29 ± 24.69
# auc_score_original                                                     51.73 ± 13.22
# acc_score_original                                                     36.25 ± 14.05
# fpr_score_original                                                     88.18 ± 14.57
# precision_score_original                                               84.00 ± 17.22
# Are NA1 NA2 Different?                                                         False
# Cohen's d (NA1 vs NA2)                                                      0.655169
# Cohen's d (NA2 vs Response)                                                -0.447212
# Cohen's d (NA2 vs Problem)                                                  0.728185
# Cohen's d (Response vs Problem)                                             0.447214
# Tukey_HSD                          No significant differences found by ANOVA.\n  ...
# Name: 15, dtype: object acc
# index: 15 Unnamed: 0                                                                     지구과학Ⅱ
# auc_score                                                              82.57 ± 13.05
# acc_score                                                               87.17 ± 8.93
# fpr_score                                                                2.87 ± 3.79
# precision_score                                                        51.29 ± 24.69
# auc_score_original                                                     51.73 ± 13.22
# acc_score_original                                                     36.25 ± 14.05
# fpr_score_original                                                     88.18 ± 14.57
# precision_score_original                                               84.00 ± 17.22
# Are NA1 NA2 Different?                                                         False
# Cohen's d (NA1 vs NA2)                                                      0.655169
# Cohen's d (NA2 vs Response)                                                -0.447212
# Cohen's d (NA2 vs Problem)                                                  0.728185
# Cohen's d (Response vs Problem)                                             0.447214
# Tukey_HSD                          No significant differences found by ANOVA.\n  ...
# Name: 15, dtype: object fpr
# index: 15 Unnamed: 0                                                                     지구과학Ⅱ
# auc_score                                                              82.57 ± 13.05
# acc_score                                                               87.17 ± 8.93
# fpr_score                                                                2.87 ± 3.79
# precision_score                                                        51.29 ± 24.69
# auc_score_original                                                     51.73 ± 13.22
# acc_score_original                                                     36.25 ± 14.05
# fpr_score_original                                                     88.18 ± 14.57
# precision_score_original                                               84.00 ± 17.22
# Are NA1 NA2 Different?                                                         False
# Cohen's d (NA1 vs NA2)                                                      0.655169
# Cohen's d (NA2 vs Response)                                                -0.447212
# Cohen's d (NA2 vs Problem)                                                  0.728185
# Cohen's d (Response vs Problem)                                             0.447214
# Tukey_HSD                          No significant differences found by ANOVA.\n  ...
# Name: 15, dtype: object precision
# index: 16 Unnamed: 0                                                                      통합과학
# auc_score                                                               94.08 ± 0.40
# acc_score                                                               88.71 ± 0.58
# fpr_score                                                                7.93 ± 0.78
# precision_score                                                         87.32 ± 0.89
# auc_score_original                                                               NaN
# acc_score_original                                                               NaN
# fpr_score_original                                                               NaN
# precision_score_original                                                         NaN
# Are NA1 NA2 Different?                                                         False
# Cohen's d (NA1 vs NA2)                                                      0.116635
# Cohen's d (NA2 vs Response)                                                 0.457444
# Cohen's d (NA2 vs Problem)                                                  0.335679
# Cohen's d (Response vs Problem)                                            -0.131118
# Tukey_HSD                          No significant differences found by ANOVA.\n M...
# Name: 16, dtype: object auc
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[12], line 8
#       6 print('index:', index, row, criteria)
#       7 mean, std = parse_mean_std(row[f'{criteria}_score'])
# ----> 8 original_mean, original_std = parse_mean_std(row[f'{criteria}_score_original'])
#       9 abs_diff = abs(mean - original_mean)
#      10 sum_std = std + original_std
#
# Cell In[11], line 2, in parse_mean_std(value)
#       1 def parse_mean_std(value):
# ----> 2     mean, std = value.split('±')
#       3     return float(mean.strip()), float(std.strip())
#
# AttributeError: 'float' object has no attribute 'split'

# %% [markdown]
# ## delete files from all folders

# %%
do not run this cell carelessly

# %%
# import os

# # Define base directories
# base_dirs = [
#     '/root/jw/EduCDM/examples/IRT/GD/results_NA1',
#     '/root/jw/EduCDM/examples/IRT/GD/results_NA2'
# ]

# for base_dir in base_dirs:
#     actual_folders = [folder for folder in os.listdir(base_dir) if os.path.isdir(os.path.join(base_dir, folder))]
#     for subject in actual_folders:
#         subject_path = os.path.join(base_dir, subject)
#         for file_name in os.listdir(subject_path):
#             #if file.startswith('best_params_') and file.endswith('.txt'):
#             if file_name in ['NA2_info_comparison.csv', 'NA1_info_comparison.csv']:
#                 file_path = os.path.join(subject_path, file_name)
#                 # Delete the file
#                 os.remove(file_path)
#                 print(f"Deleted file: {file_path}")
